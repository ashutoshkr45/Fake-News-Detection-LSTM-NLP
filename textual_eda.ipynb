# %% [markdown]
# ## Importing Libraries and Custom Visualization Utilities

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from viz_utils import (
    plot_label_distribution,
    plot_label_count,
    plot_article_lengths,
    plot_top_authors,
    plot_word_cloud,
    plot_title_lengths
)

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/data/train.csv')

# %%
df.shape
# Out:
# (20800, 5)

# %% [markdown]
# #### Checking for Missing Data

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %% [markdown]
# >The dataset contains missing values in several columns: *558*  in `title`, *1957*  in `author`, and *39*  in `text`.

# %% [markdown]
# **Removing rows with any missing values from the DataFrame.**

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (18285, 5)

# %% [markdown]
# ## Visualizations

# %% [markdown]
# Displaying the distribution of labels in the dataset.

# %%
plot_label_distribution(df)

# %%
plot_label_count(df)

# %% [markdown]
# >***The dataset is reasonably balanced, with no extreme imbalance between the classes.***

# %% [markdown]
# ##### Analyzing Article and Title Lengths

# %%
plot_article_lengths(df)

# %% [markdown]
# > ***As the length of the articles increase, they tend to be more reliable.***

# %%
# Plot title lengths
plot_title_lengths(df)

# %% [markdown]
# > ***Longer titles are associated with higher reliability, while shorter titles show an even stronger tendency towards being fake.***

# %% [markdown]
# Revealing the distribution of articles among different Authors.

# %%
plot_top_authors(df)

# %% [markdown]
# > **Author *Pam Key* has the highest number of articles, around 240. Notably, authors such as 'admin', 'Pakalert', and 'Eddy Lavine' exclusively contribute fake articles, as indicated by their bars being completely red.**

# %% [markdown]
# ## WordClouds

# %%
text = ' '.join(df['text'].dropna().tolist())
plot_word_cloud(text, 'Most Common Words in Articles')

# %%
text = ' '.join(df['title'])
plot_word_cloud(text, 'Most Common Words in Article Titles')
